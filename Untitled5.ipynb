# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishvajeet-hue/Vishuu-python-/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
str1 = "Python"
print("Length:", len(str1))
# Out:
# Length: 6

# %%
str1 = "Python"

if len(str1) < 2:
    print("Empty String")
else:
    result = str1[:2] + str1[-2:]
    print(result)
# Out:
# Pyon

# %%
str1 = "Hello"
str2 = "World"

print("Result:", str1 + str2)
# Out:
# Result: HelloWorld
