# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishvajeet-hue/Vishuu-python-/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 20
b = 20

sum = a + b
print("Sum =", sum)
# Out:
# Sum = 40

# %%
a = 10
b = 3.5
c = "Hello"
d = True

print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a = "100"

# Convert string to integer
b = int(a)

print("Original type:", type(a))
print("After casting:", type(b))
print("Value:", b)
# Out:
# Original type: <class 'str'>
# After casting: <class 'int'>
# Value: 100

# %%
a = True
b = False

print("AND:", a and b)
print("OR:", a or b)
print("NOT:", not a)
# Out:
# AND: False
# OR: True
# NOT: False
